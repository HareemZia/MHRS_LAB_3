# %%
from rasterio.plot import show
import geos
import rasterio
import geotiff
import tifffile
import matplotlib.pyplot as plt #For plotting our visualizations
from keras.preprocessing.image import ImageDataGenerator #Keras dataset generator class.
from numpy import expand_dims
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
import cv2
from PIL import Image

# %matplotlib inline 
image1 = rasterio.open("E:\MHS labs\Lab data (Ormara)\HH-ALPSRP240640490-H2.2_UA.tif")
show(image1)
image2 = rasterio.open("E:\MHS labs\Lab data (Ormara)\HV-ALPSRP240640490-H2.2_UA.tif")
show(image2)
# Out:
# <Axes: >

# %%
#ROTATING IMAGE
from rasterio.plot import show
import rasterio
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from numpy import expand_dims
from keras.preprocessing.image import img_to_array

image_path = "E:\MHS labs\Lab data (Ormara)\HH-ALPSRP240640490-H2.2_UA.tif"
image = rasterio.open(image_path)
data = image.read()
data = data.transpose(1, 2, 0) 

samples = expand_dims(data, 0)
data_generator = ImageDataGenerator(rotation_range=90)
it = data_generator.flow(samples, batch_size=1)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

show(image)
# Out:
# <Axes: >

# %%
#ROTATING IMAGE 2
from rasterio.plot import show
import rasterio
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from numpy import expand_dims
from keras.preprocessing.image import img_to_array
image_path = "E:\MHS labs\Lab data (Ormara)\HV-ALPSRP240640490-H2.2_UA.tif"
image = rasterio.open(image_path)

data = image.read()
data = data.transpose(1, 2, 0)  

samples = expand_dims(data, 0)
data_generator = ImageDataGenerator(rotation_range=90)
it = data_generator.flow(samples, batch_size=1)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

show(image)
# Out:
# <Axes: >

# %%
#SHIFTING IMAGE TILE HORIZONTALLLY
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator
image_path = "E:\MHS labs\Lab data (Ormara)\HH-ALPSRP240640490-H2.2_UA.tif"
image = rasterio.open(image_path)

data = image.read()
data = data.transpose(1, 2, 0)

samples = expand_dims(data, 0)
data_generator = ImageDataGenerator(height_shift_range=0.5)
it = data_generator.flow(samples, batch_size=1)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()

# %%
#SHIFTING IMAGE TILE HORIZONTALLLY (FOR IMAGE 2)
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator
image_path = "E:\MHS labs\Lab data (Ormara)\HV-ALPSRP240640490-H2.2_UA.tif"
image = rasterio.open(image_path)

data = image.read()
data = data.transpose(1, 2, 0)

samples = expand_dims(data, 0)
data_generator = ImageDataGenerator(height_shift_range=0.5)
it = data_generator.flow(samples, batch_size=1)

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()

# %%
#SHIFTING IMAGE VERTICALLY
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator
image_path = "E:\MHS labs\Lab data (Ormara)\HH-ALPSRP240640490-H2.2_UA.tif"
image = rasterio.open(image_path)

data = image.read()
data = data.transpose(1, 2, 0)
samples = expand_dims(data, 0)
data_generator = ImageDataGenerator(width_shift_range=0.5)
it = data_generator.flow(samples, batch_size=1)

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()

# %%
#SHIFTING IMAGE VERTICALLY
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator
image_path = "E:\MHS labs\Lab data (Ormara)\HV-ALPSRP240640490-H2.2_UA.tif"
image = rasterio.open(image_path)

data = image.read()
data = data.transpose(1, 2, 0)
samples = expand_dims(data, 0)
data_generator = ImageDataGenerator(width_shift_range=0.5)
it = data_generator.flow(samples, batch_size=1)

import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()

# %%
#TO ENHANCE THE COLOR OF THE IMAGE
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator, img_to_array
import matplotlib.pyplot as plt
image_path = "E:\MHS labs\Lab data (Ormara)\HH-ALPSRP240640490-H2.2_UA.tif"
image = rasterio.open(image_path)

data = image.read()
data = data.transpose(1, 2, 0)

samples = expand_dims(data, 0)
datagen = ImageDataGenerator(brightness_range=[0.5, 1])
it = datagen.flow(samples, batch_size=1)
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()

# %%
#TO ENHANCE THE COLOR OF THE IMAGE(FOR IMAGE 2)
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator, img_to_array
import matplotlib.pyplot as plt
image_path = "E:\MHS labs\Lab data (Ormara)\HV-ALPSRP240640490-H2.2_UA.tif"
image = rasterio.open(image_path)

data = image.read()
data = data.transpose(1, 2, 0)

samples = expand_dims(data, 0)
datagen = ImageDataGenerator(brightness_range=[0.5, 1])
it = datagen.flow(samples, batch_size=1)
plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()

# %%
# ZOOMIN IN
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator, img_to_array
import matplotlib.pyplot as plt
image_path = "E:\MHS labs\Lab data (Ormara)\HH-ALPSRP240640490-H2.2_UA.tif"
image = rasterio.open(image_path)

data = image.read()
data = data.transpose(1, 2, 0)
samples = expand_dims(data, 0)
datagen = ImageDataGenerator(zoom_range=[1,10])
it = datagen.flow(samples, batch_size=1)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()

# %%
# ZOOMING IN (IMAGE 2)
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator, img_to_array
import matplotlib.pyplot as plt
image_path = "E:\MHS labs\Lab data (Ormara)\HV-ALPSRP240640490-H2.2_UA.tif"
image = rasterio.open(image_path)

data = image.read()
data = data.transpose(1, 2, 0)
samples = expand_dims(data, 0)
datagen = ImageDataGenerator(zoom_range=[1,10])
it = datagen.flow(samples, batch_size=1)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()

# %%
#FLIPPING IMAGE 1
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator, img_to_array
import matplotlib.pyplot as plt
image_path = "E:\MHS labs\Lab data (Ormara)\HH-ALPSRP240640490-H2.2_UA.tif"
image = rasterio.open(image_path)

data = image.read()
data = data.transpose(1, 2, 0)
samples = expand_dims(data, 0)
datagen = ImageDataGenerator(vertical_flip=True)
it = datagen.flow(samples, batch_size=1)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()

# %%
#FLIPPING IMAGE 2
from rasterio.plot import show
import rasterio
from numpy import expand_dims
from keras.preprocessing.image import ImageDataGenerator, img_to_array
import matplotlib.pyplot as plt
image_path = "E:\MHS labs\Lab data (Ormara)\HV-ALPSRP240640490-H2.2_UA.tif"
image = rasterio.open(image_path)

data = image.read()
data = data.transpose(1, 2, 0)
samples = expand_dims(data, 0)
datagen = ImageDataGenerator(vertical_flip=True)
it = datagen.flow(samples, batch_size=1)

plt.figure(figsize=(10, 10))
for i in range(9):
    plt.subplot(330 + 1 + i)
    batch = it.next()
    result = batch[0].astype('uint16')
    plt.imshow(result)

plt.show()
